# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\supriya\\Downloads\\linear regression model for house price predicition\\business.csv")

# %%
df
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1      11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2      11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3      11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4      11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 93482  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483  31-03-2022    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485  31-03-2022    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
#
# ...

# %%
df.shape
# Out:
# (93487, 11)

# %%
#get basics info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93487 entries, 0 to 93486
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        93487 non-null  object
#  1   airline     93487 non-null  object
#  2   ch_code     93487 non-null  object
#  3   num_code    93487 non-null  int64
#  4   dep_time    93487 non-null  object
#  5   from        93487 non-null  object
#  6   time_taken  93487 non-null  object
#  7   stop        93487 non-null  object
#  8   arr_time    93487 non-null  object
#  9   to          93487 non-null  object
#  10  price       93487 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 7.8+ MB

# %%
df["date"] = pd.to_datetime(df["date"], dayfirst=True)  # Set dayfirst=True for DD/MM/YYYY
df["day"] = df["date"].dt.day
df["month"] = df["date"].dt.month
df["year"] = df["date"].dt.year

# %%
df
# Out:
#             date    airline ch_code  num_code dep_time     from time_taken  \
# 0     2022-02-11  Air India      AI       868    18:00    Delhi    02h 00m
# 1     2022-02-11  Air India      AI       624    19:00    Delhi    02h 15m
# 2     2022-02-11  Air India      AI       531    20:00    Delhi    24h 45m
# 3     2022-02-11  Air India      AI       839    21:25    Delhi    26h 30m
# 4     2022-02-11  Air India      AI       544    17:15    Delhi    06h 40m
# ...          ...        ...     ...       ...      ...      ...        ...
# 93482 2022-03-31    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483 2022-03-31    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484 2022-03-31    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485 2022-03-31    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486 2022-03-31    Vistara      UK       822    09:45  Chennai    10h 05m
#
# ...

# %%
df.drop("date",axis=1,inplace=True)

# %%
df
# Out:
#          airline ch_code  num_code dep_time     from time_taken  \
# 0      Air India      AI       868    18:00    Delhi    02h 00m
# 1      Air India      AI       624    19:00    Delhi    02h 15m
# 2      Air India      AI       531    20:00    Delhi    24h 45m
# 3      Air India      AI       839    21:25    Delhi    26h 30m
# 4      Air India      AI       544    17:15    Delhi    06h 40m
# ...          ...     ...       ...      ...      ...        ...
# 93482    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486    Vistara      UK       822    09:45  Chennai    10h 05m
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     20:00     Mumbai
# ...

# %%
print(type(df["time_taken"].iloc[0]))
# Out:
# <class 'str'>

# %%
df["hours"] = df["time_taken"].str.split(" ").str[0]
df["minutes"] = df["time_taken"].str.split(" ").str[1]

# %%
df
# Out:
#          airline ch_code  num_code dep_time     from time_taken  \
# 0      Air India      AI       868    18:00    Delhi    02h 00m
# 1      Air India      AI       624    19:00    Delhi    02h 15m
# 2      Air India      AI       531    20:00    Delhi    24h 45m
# 3      Air India      AI       839    21:25    Delhi    26h 30m
# 4      Air India      AI       544    17:15    Delhi    06h 40m
# ...          ...     ...       ...      ...      ...        ...
# 93482    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486    Vistara      UK       822    09:45  Chennai    10h 05m
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     20:00     Mumbai
# ...

# %%
df.drop("time_taken", axis=1,inplace=True)

# %%
df
# Out:
#          airline ch_code  num_code dep_time     from  \
# 0      Air India      AI       868    18:00    Delhi
# 1      Air India      AI       624    19:00    Delhi
# 2      Air India      AI       531    20:00    Delhi
# 3      Air India      AI       839    21:25    Delhi
# 4      Air India      AI       544    17:15    Delhi
# ...          ...     ...       ...      ...      ...
# 93482    Vistara      UK       822    09:45  Chennai
# 93483    Vistara      UK       826    12:30  Chennai
# 93484    Vistara      UK       832    07:05  Chennai
# 93485    Vistara      UK       828    07:00  Chennai
# 93486    Vistara      UK       822    09:45  Chennai
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     20:00     Mumbai
# 1                                              non-stop     21:15     Mumbai
# 2      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45     Mumbai
# ...

# %%
df.head()
# Out:
#      airline ch_code  num_code dep_time   from  \
# 0  Air India      AI       868    18:00  Delhi
# 1  Air India      AI       624    19:00  Delhi
# 2  Air India      AI       531    20:00  Delhi
# 3  Air India      AI       839    21:25  Delhi
# 4  Air India      AI       544    17:15  Delhi
#
#                                                 stop arr_time      to   price  \
# 0                                          non-stop     20:00  Mumbai  25,612
# 1                                          non-stop     21:15  Mumbai  25,612
# 2  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45  Mumbai  42,220
# 3  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  44,450
# 4  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  46,690
#
#    day  month  year hours minutes
# 0   11      2  2022   02h     00m
# 1   11      2  2022   02h     15m
# 2   11      2  2022   24h     45m
# 3   11      2  2022   26h     30m
# 4   11      2  2022   06h     40m

# %%
df["arr_hours"] = df["arr_time"].str.split(":").str[0]
df["arr_minutes"] = df["arr_time"].str.split(" ").str[1]

# %%
df
# Out:
#          airline ch_code  num_code dep_time     from  \
# 0      Air India      AI       868    18:00    Delhi
# 1      Air India      AI       624    19:00    Delhi
# 2      Air India      AI       531    20:00    Delhi
# 3      Air India      AI       839    21:25    Delhi
# 4      Air India      AI       544    17:15    Delhi
# ...          ...     ...       ...      ...      ...
# 93482    Vistara      UK       822    09:45  Chennai
# 93483    Vistara      UK       826    12:30  Chennai
# 93484    Vistara      UK       832    07:05  Chennai
# 93485    Vistara      UK       828    07:00  Chennai
# 93486    Vistara      UK       822    09:45  Chennai
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     20:00     Mumbai
# 1                                              non-stop     21:15     Mumbai
# 2      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45     Mumbai
# ...

# %%
df["arr_time"] = df["arr_time"].astype(str)
df["arr_minutes"] = df["arr_time"].str.split(":").str[1]

# %%
df
# Out:
#          airline ch_code  num_code     from  \
# 0      Air India      AI       868    Delhi
# 1      Air India      AI       624    Delhi
# 2      Air India      AI       531    Delhi
# 3      Air India      AI       839    Delhi
# 4      Air India      AI       544    Delhi
# ...          ...     ...       ...      ...
# 93482    Vistara      UK       822  Chennai
# 93483    Vistara      UK       826  Chennai
# 93484    Vistara      UK       832  Chennai
# 93485    Vistara      UK       828  Chennai
# 93486    Vistara      UK       822  Chennai
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     20:00     Mumbai
# 1                                              non-stop     21:15     Mumbai
# 2      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45     Mumbai
# 3      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# ...

# %%
df["dep_hour"] = df["dep_time"].str.split(":").str[0]
df["dep_minutes"] = df["dep_time"].str.split(":").str[1]

# %%
df
# Out:
#          airline ch_code  num_code dep_time     from  \
# 0      Air India      AI       868    18:00    Delhi
# 1      Air India      AI       624    19:00    Delhi
# 2      Air India      AI       531    20:00    Delhi
# 3      Air India      AI       839    21:25    Delhi
# 4      Air India      AI       544    17:15    Delhi
# ...          ...     ...       ...      ...      ...
# 93482    Vistara      UK       822    09:45  Chennai
# 93483    Vistara      UK       826    12:30  Chennai
# 93484    Vistara      UK       832    07:05  Chennai
# 93485    Vistara      UK       828    07:00  Chennai
# 93486    Vistara      UK       822    09:45  Chennai
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     20:00     Mumbai
# 1                                              non-stop     21:15     Mumbai
# 2      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45     Mumbai
# ...

# %%
df.drop("dep_time",axis=1,inplace=True)

# %%
df
# Out:
#          airline ch_code  num_code     from  \
# 0      Air India      AI       868    Delhi
# 1      Air India      AI       624    Delhi
# 2      Air India      AI       531    Delhi
# 3      Air India      AI       839    Delhi
# 4      Air India      AI       544    Delhi
# ...          ...     ...       ...      ...
# 93482    Vistara      UK       822  Chennai
# 93483    Vistara      UK       826  Chennai
# 93484    Vistara      UK       832  Chennai
# 93485    Vistara      UK       828  Chennai
# 93486    Vistara      UK       822  Chennai
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     20:00     Mumbai
# 1                                              non-stop     21:15     Mumbai
# 2      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45     Mumbai
# 3      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# ...

# %%
df.drop("arr_time", axis=1, inplace=True)

# %%
df
# Out:
#          airline ch_code  num_code     from  \
# 0      Air India      AI       868    Delhi
# 1      Air India      AI       624    Delhi
# 2      Air India      AI       531    Delhi
# 3      Air India      AI       839    Delhi
# 4      Air India      AI       544    Delhi
# ...          ...     ...       ...      ...
# 93482    Vistara      UK       822  Chennai
# 93483    Vistara      UK       826  Chennai
# 93484    Vistara      UK       832  Chennai
# 93485    Vistara      UK       828  Chennai
# 93486    Vistara      UK       822  Chennai
#
#                                                     stop         to   price  \
# 0                                              non-stop      Mumbai  25,612
# 1                                              non-stop      Mumbai  25,612
# 2      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...     Mumbai  42,220
# 3      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...     Mumbai  44,450
# ...

# %%
df["stop"].unique()
# Out:
# array(['non-stop ',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IDR\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXU\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Chennai\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Lucknow\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia STV\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Hyderabad\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia GAY\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '2+-stop',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Guwahati\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia GAU\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia VTZ\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia NDC\n\t\t\t\t\t\t\t\t\t\t\t\t',
# ...

# %%
df[df["stop"].isnull()]
# Out:
# Empty DataFrame
# Columns: [airline, ch_code, num_code, from, stop, to, price, day, month, year, hours, minutes, arr_hours, arr_minutes, dep_hour, dep_minutes]
# Index: []

# %%
df["stop"]=df["stop"].str.replace(r'\s+','',regex=True).str.strip()

# %%
df
# Out:
#          airline ch_code  num_code     from      stop         to   price  day  \
# 0      Air India      AI       868    Delhi  non-stop     Mumbai  25,612   11
# 1      Air India      AI       624    Delhi  non-stop     Mumbai  25,612   11
# 2      Air India      AI       531    Delhi    1-stop     Mumbai  42,220   11
# 3      Air India      AI       839    Delhi    1-stop     Mumbai  44,450   11
# 4      Air India      AI       544    Delhi    1-stop     Mumbai  46,690   11
# ...          ...     ...       ...      ...       ...        ...     ...  ...
# 93482    Vistara      UK       822  Chennai    1-stop  Hyderabad  69,265   31
# 93483    Vistara      UK       826  Chennai    1-stop  Hyderabad  77,105   31
# 93484    Vistara      UK       832  Chennai    1-stop  Hyderabad  79,099   31
# 93485    Vistara      UK       828  Chennai    1-stop  Hyderabad  81,585   31
# 93486    Vistara      UK       822  Chennai    1-stop  Hyderabad  81,585   31
#
# ...

# %%
df.rename(columns={"from":"source"},inplace=True)
df.rename(columns={"to":"destination"},inplace=True)

# %%
df
# Out:
#          airline ch_code  num_code   source      stop destination   price  \
# 0      Air India      AI       868    Delhi  non-stop      Mumbai  25,612
# 1      Air India      AI       624    Delhi  non-stop      Mumbai  25,612
# 2      Air India      AI       531    Delhi    1-stop      Mumbai  42,220
# 3      Air India      AI       839    Delhi    1-stop      Mumbai  44,450
# 4      Air India      AI       544    Delhi    1-stop      Mumbai  46,690
# ...          ...     ...       ...      ...       ...         ...     ...
# 93482    Vistara      UK       822  Chennai    1-stop   Hyderabad  69,265
# 93483    Vistara      UK       826  Chennai    1-stop   Hyderabad  77,105
# 93484    Vistara      UK       832  Chennai    1-stop   Hyderabad  79,099
# 93485    Vistara      UK       828  Chennai    1-stop   Hyderabad  81,585
# 93486    Vistara      UK       822  Chennai    1-stop   Hyderabad  81,585
#
#        day  month  year hours minutes arr_hours arr_minutes dep_hour  \
# ...

# %%
# Out:
#          airline ch_code  num_code   source      stop destination   price  \
# 0      Air India      AI       868    Delhi  non-stop      Mumbai  25,612
# 1      Air India      AI       624    Delhi  non-stop      Mumbai  25,612
# 2      Air India      AI       531    Delhi    1-stop      Mumbai  42,220
# 3      Air India      AI       839    Delhi    1-stop      Mumbai  44,450
# 4      Air India      AI       544    Delhi    1-stop      Mumbai  46,690
# ...          ...     ...       ...      ...       ...         ...     ...
# 93482    Vistara      UK       822  Chennai    1-stop   Hyderabad  69,265
# 93483    Vistara      UK       826  Chennai    1-stop   Hyderabad  77,105
# 93484    Vistara      UK       832  Chennai    1-stop   Hyderabad  79,099
# 93485    Vistara      UK       828  Chennai    1-stop   Hyderabad  81,585
# 93486    Vistara      UK       822  Chennai    1-stop   Hyderabad  81,585
#
#        day  month  year hours minutes arr_hours arr_minutes dep_hour  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93487 entries, 0 to 93486
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   airline      93487 non-null  object
#  1   ch_code      93487 non-null  object
#  2   num_code     93487 non-null  int64
#  3   source       93487 non-null  object
#  4   stop         93487 non-null  object
#  5   destination  93487 non-null  object
#  6   price        93487 non-null  object
#  7   day          93487 non-null  int32
#  8   month        93487 non-null  int32
#  9   year         93487 non-null  int32
#  10  hours        93487 non-null  object
#  11  minutes      93487 non-null  object
#  12  arr_hours    93487 non-null  object
#  13  arr_minutes  93487 non-null  object
#  14  dep_hour     93487 non-null  object
#  15  dep_minutes  93487 non-null  object
# dtypes: int32(3), int64(1), object(12)
# memory usage: 10.3+ MB

# %%
df.to_csv("flights_data_csv",index=False)

# %%
# Out:
#          airline ch_code  num_code   source      stop destination   price  \
# 0      Air India      AI       868    Delhi  non-stop      Mumbai  25,612
# 1      Air India      AI       624    Delhi  non-stop      Mumbai  25,612
# 2      Air India      AI       531    Delhi    1-stop      Mumbai  42,220
# 3      Air India      AI       839    Delhi    1-stop      Mumbai  44,450
# 4      Air India      AI       544    Delhi    1-stop      Mumbai  46,690
# ...          ...     ...       ...      ...       ...         ...     ...
# 93482    Vistara      UK       822  Chennai    1-stop   Hyderabad  69,265
# 93483    Vistara      UK       826  Chennai    1-stop   Hyderabad  77,105
# 93484    Vistara      UK       832  Chennai    1-stop   Hyderabad  79,099
# 93485    Vistara      UK       828  Chennai    1-stop   Hyderabad  81,585
# 93486    Vistara      UK       822  Chennai    1-stop   Hyderabad  81,585
#
#        day  month  year hours minutes arr_hours arr_minutes dep_hour  \
# ...
